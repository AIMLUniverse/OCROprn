# %% [markdown]
# ## Bank Document classification

# %%
'''
Code Developed by 
'''

# %%
# All imports here
import urllib.request
import json
import os
import ssl
import base64
import cv2
from IPython.display import Image

# %%
def allowSelfSignedHttps(allowed):
    # bypass the server certificate verification on client side
    if allowed and not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None):
        ssl._create_default_https_context = ssl._create_unverified_context

allowSelfSignedHttps(True) # this line is needed if you use self-signed certificate in your scoring service.

# Request data goes here
data = {
    "Inputs": {
        "WebServiceInput0":
        [
            {
                'image': "data:image/png;base64,",
                'id': "0",
                'category': "space_wolf",
            },
        ],
    },
    "GlobalParameters": {
    }
}

# %%
def classifyimage(img_filepath):
    # Create base64 encoded string
    with open(img_filepath, "rb") as f:
        image_string = base64.b64encode(f.read()).decode("utf-8")
    image_data = str(f"""data:image/png;base64,{image_string}""")
    data['Inputs']['WebServiceInput0'][0]['image'] = image_data

    body = str.encode(json.dumps(data))

    url = 'http://0ddc3999-cb56-422e-8d68-9e9195982aa3.eastus2.azurecontainer.io/score'
    api_key = 'w4RSeKKiRRNAfeCPPAsIXNXEoygwbT5P' # Replace this with the API key for the web service
    headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ api_key)}

    req = urllib.request.Request(url, body, headers)
    
    try:
        response = urllib.request.urlopen(req)

        result = response.read()
        print(result)
    except urllib.error.HTTPError as error:
        print("The request failed with status code: " + str(error.code))

        # Print the headers - they include the requert ID and the timestamp, which are useful for debugging the failure
        print(error.info())
        print(json.loads(error.read().decode("utf8", 'ignore')))

# %%
# Save string of image file path below
img_filepath = "/home/ustuser/official/AIBeta/smartvision2021/internetdataset/BankData/PAN/SANGEETA-PAN-CARD.jpg"
pil_img = Image(filename=img_filepath)
display(pil_img)

# %%
classifyimage(img_filepath)
# Out:
# b'{"Results": {"WebServiceOutput0": [{"category": "space_wolf", "id": "0", "Scored Probabilities_AccountOpeningForms": 1.0320852197764907e-05, "Scored Probabilities_AccountStatements": 1.9773090116359526e-06, "Scored Probabilities_Adhaar": 0.00020649994257837534, "Scored Probabilities_Agreements": 1.7568505427334458e-05, "Scored Probabilities_Applicationforms": 4.271215402695816e-06, "Scored Probabilities_Certificates": 4.146709034102969e-05, "Scored Probabilities_ConfidentialReports": 3.200373612344265e-05, "Scored Probabilities_CustomerRequestForms": 0.00027124863117933273, "Scored Probabilities_PAN": 0.9994118213653564, "Scored Probabilities_Reports": 2.7870141821040306e-06, "Scored Labels": "PAN"}]}}'

# %%
img_filepath = "/home/ustuser/official/AIBeta/smartvision2021/internetdataset/BankData/AccountStatements/1d58e1e6f2bcde379bef487370c422e1d.png"
pil_img = Image(filename=img_filepath)
display(pil_img)

# %%
classifyimage(img_filepath)
# Out:
# b'{"Results": {"WebServiceOutput0": [{"category": "space_wolf", "id": "0", "Scored Probabilities_AccountOpeningForms": 1.4678080333396792e-05, "Scored Probabilities_AccountStatements": 0.9838880896568298, "Scored Probabilities_Adhaar": 4.93100117182621e-07, "Scored Probabilities_Agreements": 7.269954494404374e-06, "Scored Probabilities_Applicationforms": 7.241201092256233e-05, "Scored Probabilities_Certificates": 2.0416877305251546e-05, "Scored Probabilities_ConfidentialReports": 1.6276542737614363e-05, "Scored Probabilities_CustomerRequestForms": 4.591333890857641e-06, "Scored Probabilities_PAN": 5.7129718697979115e-06, "Scored Probabilities_Reports": 0.015970179811120033, "Scored Labels": "AccountStatements"}]}}'

# %%
img_filepath = "/home/ustuser/official/AIBeta/smartvision2021/internetdataset/BankData/AccountOpeningForms/100071222169.png"
pil_img = Image(filename=img_filepath)
display(pil_img)

# %%
classifyimage(img_filepath)
# Out:
# b'{"Results": {"WebServiceOutput0": [{"category": "space_wolf", "id": "0", "Scored Probabilities_AccountOpeningForms": 0.6725871562957764, "Scored Probabilities_AccountStatements": 0.004444282967597246, "Scored Probabilities_Adhaar": 0.0015257088234648108, "Scored Probabilities_Agreements": 0.005396861582994461, "Scored Probabilities_Applicationforms": 0.2046564370393753, "Scored Probabilities_Certificates": 0.006611878518015146, "Scored Probabilities_ConfidentialReports": 0.018719201907515526, "Scored Probabilities_CustomerRequestForms": 0.04857514053583145, "Scored Probabilities_PAN": 0.0011240380117669702, "Scored Probabilities_Reports": 0.036359332501888275, "Scored Labels": "AccountOpeningForms"}]}}'

# %%
img_filepath = "/home/ustuser/official/AIBeta/smartvision2021/internetdataset/BankData/AccountOpeningForms/42288345.png"
pil_img = Image(filename=img_filepath)
display(pil_img)

# %%
classifyimage(img_filepath)
# Out:
# b'{"Results": {"WebServiceOutput0": [{"category": "space_wolf", "id": "0", "Scored Probabilities_AccountOpeningForms": 0.2897719442844391, "Scored Probabilities_AccountStatements": 0.005080848000943661, "Scored Probabilities_Adhaar": 0.006055533420294523, "Scored Probabilities_Agreements": 0.053112905472517014, "Scored Probabilities_Applicationforms": 0.431112676858902, "Scored Probabilities_Certificates": 0.020142093300819397, "Scored Probabilities_ConfidentialReports": 0.007398497313261032, "Scored Probabilities_CustomerRequestForms": 0.008195302449166775, "Scored Probabilities_PAN": 0.0003764911962207407, "Scored Probabilities_Reports": 0.17875370383262634, "Scored Labels": "Applicationforms"}]}}'

# %%
img_filepath = "/home/ustuser/official/AIBeta/smartvision2021/internetdataset/BankData/AccountStatements/9e23236469e8c4c5d7fcdaa046234c0f.jpg"
pil_img = Image(filename=img_filepath)
display(pil_img)

# %%
classifyimage(img_filepath)
# Out:
# b'{"Results": {"WebServiceOutput0": [{"category": "space_wolf", "id": "0", "Scored Probabilities_AccountOpeningForms": 0.3998588025569916, "Scored Probabilities_AccountStatements": 0.008042150177061558, "Scored Probabilities_Adhaar": 0.036750249564647675, "Scored Probabilities_Agreements": 0.04247228428721428, "Scored Probabilities_Applicationforms": 0.14294390380382538, "Scored Probabilities_Certificates": 0.024995965883135796, "Scored Probabilities_ConfidentialReports": 0.014964893460273743, "Scored Probabilities_CustomerRequestForms": 0.09139441698789597, "Scored Probabilities_PAN": 0.0024787303991615772, "Scored Probabilities_Reports": 0.23609863221645355, "Scored Labels": "AccountOpeningForms"}]}}'

# %%
img_filepath = "/home/ustuser/official/AIBeta/smartvision2021/internetdataset/BankData/Agreements/35fc4c9e-d0e6-4683-a4e0-4d6752350575_1.png"
pil_img = Image(filename=img_filepath)
display(pil_img)

# %%
classifyimage(img_filepath)
# Out:
# b'{"Results": {"WebServiceOutput0": [{"category": "space_wolf", "id": "0", "Scored Probabilities_AccountOpeningForms": 1.4786374435971084e-07, "Scored Probabilities_AccountStatements": 1.1671028232740355e-06, "Scored Probabilities_Adhaar": 1.1449307066868641e-06, "Scored Probabilities_Agreements": 0.9855183362960815, "Scored Probabilities_Applicationforms": 5.114387931826059e-06, "Scored Probabilities_Certificates": 0.014452571980655193, "Scored Probabilities_ConfidentialReports": 5.359598162613111e-06, "Scored Probabilities_CustomerRequestForms": 8.967672329163179e-06, "Scored Probabilities_PAN": 9.238898002195128e-08, "Scored Probabilities_Reports": 7.104743417585269e-06, "Scored Labels": "Agreements"}]}}'

# %%
img_filepath = "/home/ustuser/official/AIBeta/smartvision2021/internetdataset/BankData/Certificates/Bank-Certificate.png"
pil_img = Image(filename=img_filepath)
display(pil_img)

# %%
classifyimage(img_filepath)
# Out:
# b'{"Results": {"WebServiceOutput0": [{"category": "space_wolf", "id": "0", "Scored Probabilities_AccountOpeningForms": 0.01627950556576252, "Scored Probabilities_AccountStatements": 0.007195437792688608, "Scored Probabilities_Adhaar": 0.005575280636548996, "Scored Probabilities_Agreements": 0.40860310196876526, "Scored Probabilities_Applicationforms": 0.015614609234035015, "Scored Probabilities_Certificates": 0.30495694279670715, "Scored Probabilities_ConfidentialReports": 0.00660589337348938, "Scored Probabilities_CustomerRequestForms": 0.020825153216719627, "Scored Probabilities_PAN": 0.002424305770546198, "Scored Probabilities_Reports": 0.21191971004009247, "Scored Labels": "Agreements"}]}}'
